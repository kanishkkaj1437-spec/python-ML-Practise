# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#   Property_ID Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3     Apartment            106                NaN
# 1      0x68d4     Apartment            733                2.0
# 2      0x7d81     Apartment            737                4.0
# 3      0x7a57     Apartment            900                3.0
# 4      0x9409      Bungalow           2238               14.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# 1                2      Unfurnished                     1.0           No
# 2                2  Fully Furnished                     0.0           No
# 3                2      Unfurnished                     2.0          Yes
# 4                6  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
df.nunique()
# Out:
# Property_ID               39499
# Property_Type                 6
# Property_Area              4435
# Number_of_Windows            16
# Number_of_Doors               6
# Furnishing                    3
# Frequency_of_Powercuts        4
# Power_Backup                  3
# Water_Supply                  5
# Traffic_Density_Score       772
# Crime_Rate                    4
# Dust_and_Noise                3
# Air_Quality_Index           489
# Neighborhood_Review         417
# Habitability_score         6105
# dtype: int64

# %%
df.shape
# Out:
# (39499, 15)

# %%
df.isna().sum()
# Out:
# Property_ID                  0
# Property_Type                0
# Property_Area                0
# Number_of_Windows         1654
# Number_of_Doors              0
# Furnishing                1042
# Frequency_of_Powercuts    1383
# Power_Backup                 0
# Water_Supply                 0
# Traffic_Density_Score        0
# Crime_Rate                 787
# Dust_and_Noise            1219
# Air_Quality_Index            0
# Neighborhood_Review          0
# Habitability_score           0
# dtype: int64

# %%
df.head()
# Out:
#   Property_ID Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3     Apartment            106                NaN
# 1      0x68d4     Apartment            733                2.0
# 2      0x7d81     Apartment            737                4.0
# 3      0x7a57     Apartment            900                3.0
# 4      0x9409      Bungalow           2238               14.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# 1                2      Unfurnished                     1.0           No
# 2                2  Fully Furnished                     0.0           No
# 3                2      Unfurnished                     2.0          Yes
# 4                6  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
cols_to_fill_z = ['Number_of_Windows','Frequency_of_Powercuts']
df[cols_to_fill_z] = df[cols_to_fill_z].fillna(0)

# %%
df.isna().sum()
# Out:
# Property_ID                  0
# Property_Type                0
# Property_Area                0
# Number_of_Windows            0
# Number_of_Doors              0
# Furnishing                1042
# Frequency_of_Powercuts       0
# Power_Backup                 0
# Water_Supply                 0
# Traffic_Density_Score        0
# Crime_Rate                 787
# Dust_and_Noise            1219
# Air_Quality_Index            0
# Neighborhood_Review          0
# Habitability_score           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_Furnishing = LabelEncoder()

# %%
df.isna().sum()
# Out:
# Property_ID                  0
# Property_Type                0
# Property_Area                0
# Number_of_Windows            0
# Number_of_Doors              0
# Furnishing                1042
# Frequency_of_Powercuts       0
# Power_Backup                 0
# Water_Supply                 0
# Traffic_Density_Score        0
# Crime_Rate                 787
# Dust_and_Noise            1219
# Air_Quality_Index            0
# Neighborhood_Review          0
# Habitability_score           0
# dtype: int64

# %%
df[0:10]
# Out:
#   Property_ID       Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3           Apartment            106                0.0
# 1      0x68d4           Apartment            733                2.0
# 2      0x7d81           Apartment            737                4.0
# 3      0x7a57           Apartment            900                3.0
# 4      0x9409            Bungalow           2238               14.0
# 5      0xbe4e  Single-family home           1185                3.0
# 6       0xe2a  Single-family home           1779                3.0
# 7      0x2ea5              Duplex           1281                5.0
# 8      0x7a83           Apartment            268                1.0
# 9      0xb0fb           Apartment            159                2.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# ...

# %%
df['Furnishing'] = df['Furnishing'].fillna('Unfurnished')

# %%
df['Furnishing_n'] = le_Furnishing.fit_transform(df['Furnishing'])

# %%
df['Crime_Rate'] = df['Crime_Rate'].fillna('Well below average')

# %%
le_crime = LabelEncoder()

# %%
df['crime_n'] = le_crime.fit_transform(df['Crime_Rate'])

# %%
df['Dust_and_Noise'] = df['Dust_and_Noise'].fillna('Medium')

# %%
le_dust = LabelEncoder()

# %%
df['dust_n'] = le_dust.fit_transform(df['Dust_and_Noise'])

# %%
df.isna().sum()
# Out:
# Property_ID               0
# Property_Type             0
# Property_Area             0
# Number_of_Windows         0
# Number_of_Doors           0
# Furnishing                0
# Frequency_of_Powercuts    0
# Power_Backup              0
# Water_Supply              0
# Traffic_Density_Score     0
# Crime_Rate                0
# Dust_and_Noise            0
# Air_Quality_Index         0
# Neighborhood_Review       0
# Habitability_score        0
# Furnishing_n              0
# crime_n                   0
# dust_n                    0
# dtype: int64

# %%
le_pro = LabelEncoder()

# %%
df['Property_n'] = le_pro.fit_transform(df['Property_Type'])

# %%
df.head()
# Out:
#   Property_ID Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3     Apartment            106                0.0
# 1      0x68d4     Apartment            733                2.0
# 2      0x7d81     Apartment            737                4.0
# 3      0x7a57     Apartment            900                3.0
# 4      0x9409      Bungalow           2238               14.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# 1                2      Unfurnished                     1.0           No
# 2                2  Fully Furnished                     0.0           No
# 3                2      Unfurnished                     2.0          Yes
# 4                6  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
le_power = LabelEncoder()

# %%
df['Power_n'] = le_power.fit_transform(df['Power_Backup'])

# %%
le_water = LabelEncoder()

# %%
df['water_n'] = le_water.fit_transform(df['Water_Supply'])

# %%
df.head()
# Out:
#   Property_ID Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3     Apartment            106                0.0
# 1      0x68d4     Apartment            733                2.0
# 2      0x7d81     Apartment            737                4.0
# 3      0x7a57     Apartment            900                3.0
# 4      0x9409      Bungalow           2238               14.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# 1                2      Unfurnished                     1.0           No
# 2                2  Fully Furnished                     0.0           No
# 3                2      Unfurnished                     2.0          Yes
# 4                6  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score  ... Dust_and_Noise  \
# 0  Once in a day - Morning                   5.89  ...         Medium
# ...

# %%
inputt = df.drop(['Property_Type','Furnishing','Power_Backup','Water_Supply','Crime_Rate','Dust_and_Noise'],axis='columns')

# %%
inputt.head()
# Out:
#   Property_ID  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0      0x21e3            106                0.0                1
# 1      0x68d4            733                2.0                2
# 2      0x7d81            737                4.0                2
# 3      0x7a57            900                3.0                2
# 4      0x9409           2238               14.0                6
#
#    Frequency_of_Powercuts  Traffic_Density_Score  Air_Quality_Index  \
# 0                     0.0                   5.89               90.0
# 1                     1.0                   4.37               96.0
# 2                     0.0                   7.45              121.0
# 3                     2.0                   6.16              100.0
# 4                     0.0                   5.46              116.0
#
#    Neighborhood_Review  Habitability_score  Furnishing_n  crime_n  dust_n  \
# 0                 3.86               71.98             1        1       2
# ...

# %%
inputt.to_csv('clean_data.csv',index=False)

# %%
X = inputt.drop(['Property_ID','Habitability_score'],axis = 'columns')

# %%
y = inputt['Habitability_score']

# %%
X.head()
# Out:
#    Property_Area  Number_of_Windows  Number_of_Doors  Frequency_of_Powercuts  \
# 0            106                0.0                1                     0.0
# 1            733                2.0                2                     1.0
# 2            737                4.0                2                     0.0
# 3            900                3.0                2                     2.0
# 4           2238               14.0                6                     0.0
#
#    Traffic_Density_Score  Air_Quality_Index  Neighborhood_Review  \
# 0                   5.89               90.0                 3.86
# 1                   4.37               96.0                 3.55
# 2                   7.45              121.0                 3.81
# 3                   6.16              100.0                 1.34
# 4                   5.46              116.0                 4.77
#
#    Furnishing_n  crime_n  dust_n  Property_n  Power_n  water_n
# ...

# %%
y.head()
# Out:
# 0    71.98
# 1    71.20
# 2    71.39
# 3    31.46
# 4    93.70
# Name: Habitability_score, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train,y_train)

# %%
reg.score(X_test,y_test)
# Out:
# 0.553459195361041

# %%
reg.score(X_train,y_train)
# Out:
# 0.5577709687458314

# %%
dff = pd.read_csv('test.csv')

# %%
dff.head()
# Out:
#   Property_ID   Property_Type  Property_Area  Number_of_Windows  \
# 0      0x6e93       Apartment            293                3.0
# 1      0x8787       Apartment            586                4.0
# 2      0x6c17  Container Home            305                1.0
# 3      0x9dbd       Apartment            258                2.0
# 4      0xbfde        Bungalow           3031               12.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1      Unfurnished                     0.0           No
# 1                1   Semi_Furnished                     0.0           No
# 2                2   Semi_Furnished                     1.0           No
# 3                1   Semi_Furnished                     1.0           No
# 4                4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# ...

# %%
dff.nunique()
# Out:
# Property_ID               10500
# Property_Type                 6
# Property_Area              2969
# Number_of_Windows            16
# Number_of_Doors               6
# Furnishing                    3
# Frequency_of_Powercuts        4
# Power_Backup                  3
# Water_Supply                  5
# Traffic_Density_Score       685
# Crime_Rate                    4
# Dust_and_Noise                3
# Air_Quality_Index           274
# Neighborhood_Review         375
# dtype: int64

# %%
dff.isna().sum()
# Out:
# Property_ID                 0
# Property_Type               0
# Property_Area               0
# Number_of_Windows           0
# Number_of_Doors             0
# Furnishing                  0
# Frequency_of_Powercuts      0
# Power_Backup                0
# Water_Supply                0
# Traffic_Density_Score       0
# Crime_Rate                212
# Dust_and_Noise            330
# Air_Quality_Index           0
# Neighborhood_Review         0
# dtype: int64

# %%
cols_to_fill_ze = ['Number_of_Windows','Frequency_of_Powercuts']
dff[cols_to_fill_ze] = dff[cols_to_fill_ze].fillna(0)

# %%
dff['Furnishing'] = dff['Furnishing'].fillna('Unfurnished')

# %%
dff['Crime_Rate'] = dff['Crime_Rate'].fillna('Well below average')

# %%
dff['Dust_and_Noise'] = dff['Dust_and_Noise'].fillna('Medium')

# %%
dff.isna().sum()
# Out:
# Property_ID               0
# Property_Type             0
# Property_Area             0
# Number_of_Windows         0
# Number_of_Doors           0
# Furnishing                0
# Frequency_of_Powercuts    0
# Power_Backup              0
# Water_Supply              0
# Traffic_Density_Score     0
# Crime_Rate                0
# Dust_and_Noise            0
# Air_Quality_Index         0
# Neighborhood_Review       0
# dtype: int64

# %%
le_fur = LabelEncoder()
le_cri = LabelEncoder()
le_dus = LabelEncoder()
le_pro = LabelEncoder()
le_pow = LabelEncoder()
le_wat = LabelEncoder()

# %%
dff['fur_n'] = le_fur.fit_transform(dff['Furnishing'])

# %%
dff['cri_n'] = le_cri.fit_transform(dff['Crime_Rate'])

# %%
dff['dus_n'] = le_dus.fit_transform(dff['Dust_and_Noise'])

# %%
dff['pro_n'] = le_pro.fit_transform(dff['Property_Type'])

# %%
dff['pow_n'] = le_pow.fit_transform(dff['Power_Backup'])

# %%
dff['wat_n'] = le_wat.fit_transform(dff['Water_Supply'])

# %%
dff.head()
# Out:
#   Property_ID   Property_Type  Property_Area  Number_of_Windows  \
# 0      0x6e93       Apartment            293                3.0
# 1      0x8787       Apartment            586                4.0
# 2      0x6c17  Container Home            305                1.0
# 3      0x9dbd       Apartment            258                2.0
# 4      0xbfde        Bungalow           3031               12.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1      Unfurnished                     0.0           No
# 1                1   Semi_Furnished                     0.0           No
# 2                2   Semi_Furnished                     1.0           No
# 3                1   Semi_Furnished                     1.0           No
# 4                4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# ...

# %%
inputtt = dff.drop(['Property_Type','Furnishing','Power_Backup','Water_Supply','Crime_Rate','Dust_and_Noise'],axis='columns')

# %%
inputtt.to_csv('clean_test_sample.csv',index = False)

# %%
output = inputtt['Property_ID']
output.head()
# Out:
# 0    0x6e93
# 1    0x8787
# 2    0x6c17
# 3    0x9dbd
# 4    0xbfde
# Name: Property_ID, dtype: object

# %%
XX = inputtt.drop(['Property_ID'],axis = 'columns')

# %%
regg = LinearRegression().fit(X,y)

# %%
yy = regg.predict(XX)

# %%
yy
# Out:
# array([46.37405665, 73.76655291, 65.18311304, ..., 83.20491585,
#        70.85976553, 74.11063172])

# %%
import numpy as np

# %%
output['Habitability_score'] = yy

# %%
output.head()
# Out:
# 0    0x6e93
# 1    0x8787
# 2    0x6c17
# 3    0x9dbd
# 4    0xbfde
# Name: Property_ID, dtype: object

# %%
outputt = pd.read_csv('sample_submission.csv')

# %%
outputt.head()
# Out:
#   Property_ID  Habitability_score
# 0      0x21e3               71.98
# 1      0x68d4               71.20
# 2      0x7d81               71.39
# 3      0x7a57               31.46
# 4      0x9409               93.70

# %%
outputt = outputt.drop(['Property_ID'],axis='columns')

# %%
outputt.head()
# Out:
#    Habitability_score
# 0               71.98
# 1               71.20
# 2               71.39
# 3               31.46
# 4               93.70

# %%
outputt['Property_ID'] = inputtt['Property_ID']

# %%
outputt.head()
# Out:
#    Habitability_score Property_ID
# 0               71.98      0x6e93
# 1               71.20      0x8787
# 2               71.39      0x6c17
# 3               31.46      0x9dbd
# 4               93.70      0xbfde

# %%
outputt = outputt.drop(['Habitability_score'],axis='columns')

# %%
outputt.head()
# Out:
#   Property_ID
# 0      0x6e93
# 1      0x8787
# 2      0x6c17
# 3      0x9dbd
# 4      0xbfde

# %%
outputt
# Out:
#   Property_ID
# 0      0x6e93
# 1      0x8787
# 2      0x6c17
# 3      0x9dbd
# 4      0xbfde

# %%
inputtt
# Out:
#       Property_ID  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0          0x6e93            293                3.0                1
# 1          0x8787            586                4.0                1
# 2          0x6c17            305                1.0                2
# 3          0x9dbd            258                2.0                1
# 4          0xbfde           3031               12.0                4
# ...           ...            ...                ...              ...
# 10495      0x423d            961                0.0                3
# 10496      0x78c5            282                1.0                2
# 10497       0xbf3          27445                0.0                2
# 10498      0x305b           1451                2.0                3
# 10499      0x5cff            578                0.0                1
#
#        Frequency_of_Powercuts  Traffic_Density_Score  Air_Quality_Index  \
# ...

# %%
out = pd.DataFrame()

# %%
out['Property_ID'] = inputtt['Property_ID']
out
# Out:
#       Property_ID
# 0          0x6e93
# 1          0x8787
# 2          0x6c17
# 3          0x9dbd
# 4          0xbfde
# ...           ...
# 10495      0x423d
# 10496      0x78c5
# 10497       0xbf3
# 10498      0x305b
# 10499      0x5cff
#
# [10500 rows x 1 columns]

# %%
out['Habitability_score'] = regg.predict(XX)

# %%
out
# Out:
#       Property_ID  Habitability_score
# 0          0x6e93           46.374057
# 1          0x8787           73.766553
# 2          0x6c17           65.183113
# 3          0x9dbd           68.604752
# 4          0xbfde           67.083500
# ...           ...                 ...
# 10495      0x423d           60.537968
# 10496      0x78c5           75.469249
# 10497       0xbf3           83.204916
# 10498      0x305b           70.859766
# 10499      0x5cff           74.110632
#
# [10500 rows x 2 columns]

# %%
out.to_csv('sub_1.csv',index = False)

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso()
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso()

# %%
lasso_reg.score(X_test,y_test)
# Out:
# 0.4920631068789514

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-b7a8c64777c1> in <module>
# ----> 1 model.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'
