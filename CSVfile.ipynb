# %%
import pandas as pd

# %%
city_pop_file = "https://milliams.com/courses/data_analysis_python/city_pop.csv"
pd.read_csv(city_pop_file)
# Out:
#                           This is an example CSV file
# 0   The text at the top here is not part of the da...
# 1   to describe the file. You'll see this quite of...
# 2                     A -1 signifies a missing value.
# 3                              year;London;Paris;Rome
# 4                              2001;7.322;2.148;2.547
# 5                                   2006;7.652;;2.627
# 6                                      2008;-1;2.211;
# 7                                 2009;-1;2.234;2.734
# 8                                        2011;8.174;;
# 9                                 2012;-1;2.244;2.627
# 10                                       2015;8.615;;

# %%
pd.read_csv(
    city_pop_file,
    skiprows=5
    
)
# Out:
#    year;London;Paris;Rome
# 0  2001;7.322;2.148;2.547
# 1       2006;7.652;;2.627
# 2          2008;-1;2.211;
# 3     2009;-1;2.234;2.734
# 4            2011;8.174;;
# 5     2012;-1;2.244;2.627
# 6            2015;8.615;;

# %%
pd.read_csv(
    city_pop_file,
    skiprows=5,
    sep=";",
    
)
# Out:
#    year  London  Paris   Rome
# 0  2001   7.322  2.148  2.547
# 1  2006   7.652    NaN  2.627
# 2  2008  -1.000  2.211    NaN
# 3  2009  -1.000  2.234  2.734
# 4  2011   8.174    NaN    NaN
# 5  2012  -1.000  2.244  2.627
# 6  2015   8.615    NaN    NaN

# %%
pd.read_csv(
    city_pop_file,
    skiprows=5,
    sep=";",
    na_values=["-1"],
    index_col="year",
    
)
# Out:
#       London  Paris   Rome
# year
# 2001   7.322  2.148  2.547
# 2006   7.652    NaN  2.627
# 2008     NaN  2.211    NaN
# 2009     NaN  2.234  2.734
# 2011   8.174    NaN    NaN
# 2012     NaN  2.244  2.627
# 2015   8.615    NaN    NaN

# %%
census=pd.read_csv(
    city_pop_file,
    skiprows=5,
    sep=";",
    na_values=["-1"],
    index_col="year",
    
)

# %%
census["London"][2001]
# Out:
# 7.322

# %%
census["London"][2012]
# Out:
# nan

# %%
cityy="https://milliams.com/courses/data_analysis_python/cetml1659on.txt"
pd.read_csv(cityy)
# Out:
#                                                    MONTHLY MEAN CENTRAL ENGLAND TEMPERATURE (DEGREES C)
# 1659-1973 MANLEY (Q.J.R.METEOROL.SOC.                1974)                                        ...
# 1974 ON PARKER ET AL. (INT.J.CLIM.                   1992)                                        ...
# PARKER AND HORTON (INT.J.CLIM.                       2005)                                        ...
#            JAN   FEB   MAR   APR   MAY   JUN   ...                                                NaN
#  1659      3.0   4.0   6.0   7.0  11.0  13.0  1...                                                NaN
# ...                                                                                               ...
#  2016      5.4   4.9   5.8   7.5  12.5  15.2  1...                                                NaN
#  2017      4.0   6.1   8.7   8.9  13.2  16.0  1...                                                NaN
# ...

# %%
pd.read_csv(
    cityy,
    skiprows=4
)
# Out:
#                JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC     YEAR
# 0     1659      3.0   4.0   6.0   7.0  11.0  13.0  ...
# 1     1660      0.0   4.0   6.0   9.0  11.0  14.0  ...
# 2     1661      5.0   5.0   6.0   8.0  11.0  14.0  ...
# 3     1662      5.0   6.0   6.0   8.0  11.0  15.0  ...
# 4     1663      1.0   1.0   5.0   7.0  10.0  14.0  ...
# ..                                                 ...
# 357   2016      5.4   4.9   5.8   7.5  12.5  15.2  ...
# 358   2017      4.0   6.1   8.7   8.9  13.2  16.0  ...
# 359   2018      5.3   2.9   4.9   9.8  13.2  16.1  ...
# 360   2019      4.0   6.7   7.8   9.1  11.1  14.2  ...
# 361   2020      6.4   6.3   6.7  10.4  12.5  15.3  ...
#
# [362 rows x 1 columns]

# %%
pd.read_csv(
    cityy,
    skiprows=4,
    sep=" "
)
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN      1659.0         NaN         NaN         NaN         NaN
# 3           NaN      1660.0         NaN         NaN         NaN         NaN
# 4           NaN      1661.0         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 359         NaN      2016.0         NaN         NaN         NaN         NaN
# 360         NaN      2017.0         NaN         NaN         NaN         NaN
# 361         NaN      2018.0         NaN         NaN         NaN         NaN
# 362         NaN      2019.0         NaN         NaN         NaN         NaN
# 363         NaN      2020.0         NaN         NaN         NaN         NaN
#
# ...

# %%
temperature = pd.read_csv(
    "https://milliams.com/courses/data_analysis_python/cetml1659on.txt",  # file name
    skiprows=6,  # skip first 6 rows of the header
    delim_whitespace=True,  # whitespace separated columns
    na_values=["-99.9", "-99.99"],  # NaNs
)
temperature.head()
# Out:
#       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1659  3.0  4.0  6.0  7.0  11.0  13.0  16.0  16.0  13.0  10.0  5.0  2.0  8.87
# 1660  0.0  4.0  6.0  9.0  11.0  14.0  15.0  16.0  13.0  10.0  6.0  5.0  9.10
# 1661  5.0  5.0  6.0  8.0  11.0  14.0  15.0  15.0  13.0  11.0  8.0  6.0  9.78
# 1662  5.0  6.0  6.0  8.0  11.0  15.0  15.0  15.0  13.0  11.0  6.0  3.0  9.52
# 1663  1.0  1.0  5.0  7.0  10.0  14.0  15.0  15.0  13.0  10.0  7.0  5.0  8.63

# %%
temperature["JAN"]<0
# Out:
# 1659    False
# 1660    False
# 1661    False
# 1662    False
# 1663    False
#         ...
# 2016    False
# 2017    False
# 2018    False
# 2019    False
# 2020    False
# Name: JAN, Length: 362, dtype: bool

# %%
temperature[temperature["JAN"]<0]
# Out:
#       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1684 -3.0 -1.0  3.0  6.5  13.0  15.0  16.0  15.5  12.0  11.0  3.0  4.0  7.95
# 1695 -1.0  0.5  3.5  5.5   9.0  13.0  13.5  13.0  11.5   9.0  5.5  4.0  7.29
# 1709 -1.5  2.0  3.0  9.0  12.0  14.5  15.5  15.5  13.5  10.0  7.5  3.5  8.74
# 1716 -2.0  3.0  4.5  9.0  10.5  14.0  15.5  15.5  12.5   9.5  5.5  3.0  8.38
# 1740 -2.8 -1.6  3.9  6.4   8.6  12.8  15.3  14.7  14.0   5.3  3.3  2.2  6.86
# 1763 -0.8  4.9  5.4  8.9  10.2  14.6  15.3  15.3  13.1   8.3  5.8  6.2  8.95
# 1776 -1.6  3.8  6.4  9.4  10.8  14.1  16.3  15.2  12.9  10.2  6.2  4.4  9.02
# 1780 -0.9  2.1  7.9  6.3  12.8  14.2  16.8  17.6  15.6   9.1  4.4  3.2  9.12
# 1784 -0.6  1.4  2.7  5.7  13.5  13.7  15.2  14.0  14.8   7.8  5.5  0.3  7.85
# 1795 -3.1  0.8  3.9  7.7  10.9  13.2  15.2  16.6  16.0  11.7  4.5  6.6  8.71
# 1814 -2.9  1.4  2.9  9.6   9.2  12.2  16.0  14.7  12.8   8.1  4.7  4.3  7.78
# ...

# %%
len(temperature[temperature["JAN"]<0])
# Out:
# 20

# %%
temperature["JUN"].mean()
# Out:
# 14.33756906077348

# %%
tips = pd.read_csv("https://milliams.com/courses/data_analysis_python/tips.csv")
tips
# Out:
#      total_bill   tip   day    time  size
# 0         16.99  0.71   Sun  Dinner     2
# 1         10.34  1.16   Sun  Dinner     3
# 2         21.01  2.45   Sun  Dinner     3
# 3         23.68  2.32   Sun  Dinner     2
# 4         24.59  2.53   Sun  Dinner     4
# ..          ...   ...   ...     ...   ...
# 239       29.03  4.14   Sat  Dinner     3
# 240       27.18  1.40   Sat  Dinner     2
# 241       22.67  1.40   Sat  Dinner     2
# 242       17.82  1.22   Sat  Dinner     2
# 243       18.78  2.10  Thur  Dinner     2
#
# [244 rows x 5 columns]

# %%
tips[["total_bill","tip"]]
# Out:
#      total_bill   tip
# 0         16.99  0.71
# 1         10.34  1.16
# 2         21.01  2.45
# 3         23.68  2.32
# 4         24.59  2.53
# ..          ...   ...
# 239       29.03  4.14
# 240       27.18  1.40
# 241       22.67  1.40
# 242       17.82  1.22
# 243       18.78  2.10
#
# [244 rows x 2 columns]

# %%
tips.loc[2]
# Out:
# total_bill     21.01
# tip             2.45
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object

# %%
tips.loc[2,"total_bill"]
# Out:
# 21.01

# %%
tips["total_bill"].sum()
# Out:
# 4827.77

# %%
tips["total_bill"].mean()
# Out:
# 19.785942622950824

# %%
tips["tip"].max()
# Out:
# 7.0

# %%
tips["tip"].idxmax()
# Out:
# 170

# %%
idx=tips["tip"].idxmax()
tips.loc[idx]
# Out:
# total_bill     50.81
# tip              7.0
# day              Sat
# time          Dinner
# size               3
# Name: 170, dtype: object

# %%
idd=tips["total_bill"].idxmin()
tips.loc[idd,"tip"]
# Out:
# 0.7

# %%
tips["total_bill"]*100
# Out:
# 0      1699.0
# 1      1034.0
# 2      2101.0
# 3      2368.0
# 4      2459.0
#         ...
# 239    2903.0
# 240    2718.0
# 241    2267.0
# 242    1782.0
# 243    1878.0
# Name: total_bill, Length: 244, dtype: float64

# %%
tipp=tips["tip"]/tips["total_bill"]
tippo=tipp*100
tippo
# Out:
# 0       4.178929
# 1      11.218569
# 2      11.661114
# 3       9.797297
# 4      10.288735
#          ...
# 239    14.261109
# 240     5.150846
# 241     6.175562
# 242     6.846240
# 243    11.182109
# Length: 244, dtype: float64

# %%
bbp=tips["total_bill"]/tips["size"]
bbp
# Out:
# 0       8.495000
# 1       3.446667
# 2       7.003333
# 3      11.840000
# 4       6.147500
#          ...
# 239     9.676667
# 240    13.590000
# 241    11.335000
# 242     8.910000
# 243     9.390000
# Length: 244, dtype: float64

# %%
bbp.mean()
# Out:
# 7.88822950819673

# %%
bbp.std()
# Out:
# 2.9143496626220995

# %% [markdown]
# std is standard deviation

# %%
tips["bill_per_person"]=bbp
tips
# Out:
#      total_bill   tip   day    time  size  bill_per_person
# 0         16.99  0.71   Sun  Dinner     2         8.495000
# 1         10.34  1.16   Sun  Dinner     3         3.446667
# 2         21.01  2.45   Sun  Dinner     3         7.003333
# 3         23.68  2.32   Sun  Dinner     2        11.840000
# 4         24.59  2.53   Sun  Dinner     4         6.147500
# ..          ...   ...   ...     ...   ...              ...
# 239       29.03  4.14   Sat  Dinner     3         9.676667
# 240       27.18  1.40   Sat  Dinner     2        13.590000
# 241       22.67  1.40   Sat  Dinner     2        11.335000
# 242       17.82  1.22   Sat  Dinner     2         8.910000
# 243       18.78  2.10  Thur  Dinner     2         9.390000
#
# [244 rows x 6 columns]

# %%
tips[tips["day"]=="Sat"]["tip"].mean()
# Out:
# 2.095402298850575

# %%
tips[tips["day"]=="Thur"]["tip"].mean()
# Out:
# 1.9398387096774194

# %%
tips[tips["size"]>=5]
# Out:
#      total_bill   tip   day    time  size  bill_per_person
# 125       29.80  2.94  Thur   Lunch     6         4.966667
# 141       34.30  4.69  Thur   Lunch     6         5.716667
# 142       41.19  3.50  Thur   Lunch     5         8.238000
# 143       27.05  3.50  Thur   Lunch     6         4.508333
# 155       29.85  3.60   Sun  Dinner     5         5.970000
# 156       48.17  3.50   Sun  Dinner     6         8.028333
# 185       20.69  3.50   Sun  Dinner     5         4.138000
# 187       30.46  1.40   Sun  Dinner     5         6.092000
# 216       28.15  2.10   Sat  Dinner     5         5.630000

# %%
st=tips[tips["day"]=="Sat"]
st[st["total_bill"]<8]
# Out:
#      total_bill   tip  day    time  size  bill_per_person
# 67         3.07  0.70  Sat  Dinner     1             3.07
# 111        7.25  0.70  Sat  Dinner     1             7.25
# 218        7.74  1.01  Sat  Dinner     2             3.87

# %%
dttt = tips[(tips["day"]=="Sat") & (tips["total_bill"]<8)]
dttt
# Out:
#      total_bill   tip  day    time  size  bill_per_person
# 67         3.07  0.70  Sat  Dinner     1             3.07
# 111        7.25  0.70  Sat  Dinner     1             7.25
# 218        7.74  1.01  Sat  Dinner     2             3.87

# %%
tips[(tips["size"] >= 4) & (tips["time"]=="Lunch")]
# Out:
#      total_bill   tip   day   time  size  bill_per_person
# 77        27.20  2.80  Thur  Lunch     4         6.800000
# 85        34.83  3.62  Thur  Lunch     4         8.707500
# 119       24.08  2.04  Thur  Lunch     4         6.020000
# 125       29.80  2.94  Thur  Lunch     6         4.966667
# 141       34.30  4.69  Thur  Lunch     6         5.716667
# 142       41.19  3.50  Thur  Lunch     5         8.238000
# 143       27.05  3.50  Thur  Lunch     6         4.508333
# 197       43.11  3.50  Thur  Lunch     4        10.777500
# 204       20.53  2.80  Thur  Lunch     4         5.132500

# %%
temperature
# Out:
#       JAN  FEB  MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC   YEAR
# 1659  3.0  4.0  6.0   7.0  11.0  13.0  16.0  16.0  13.0  10.0  5.0  2.0   8.87
# 1660  0.0  4.0  6.0   9.0  11.0  14.0  15.0  16.0  13.0  10.0  6.0  5.0   9.10
# 1661  5.0  5.0  6.0   8.0  11.0  14.0  15.0  15.0  13.0  11.0  8.0  6.0   9.78
# 1662  5.0  6.0  6.0   8.0  11.0  15.0  15.0  15.0  13.0  11.0  6.0  3.0   9.52
# 1663  1.0  1.0  5.0   7.0  10.0  14.0  15.0  15.0  13.0  10.0  7.0  5.0   8.63
# ...   ...  ...  ...   ...   ...   ...   ...   ...   ...   ...  ...  ...    ...
# 2016  5.4  4.9  5.8   7.5  12.5  15.2  16.9  17.0  16.0  10.9  5.6  6.0  10.34
# 2017  4.0  6.1  8.7   8.9  13.2  16.0  16.8  15.6  13.5  12.4  6.8  4.8  10.58
# 2018  5.3  2.9  4.9   9.8  13.2  16.1  19.1  16.6  13.7  10.6  8.3  6.9  10.68
# 2019  4.0  6.7  7.8   9.1  11.1  14.2  17.5  17.1  14.3  10.0  6.2  5.8  10.34
# 2020  6.4  6.3  6.7  10.4  12.5  15.3  15.7   NaN   NaN   NaN  NaN  NaN    NaN
#
# [362 rows x 13 columns]

# %%
temperature.plot()
# Out:
# <AxesSubplot:>

# %%
yp=temperature["YEAR"].plot()
yp.set_ylabel(r"temperatures ($^\circ$C)")
# Out:
# Text(0, 0.5, 'temperatures ($^\\circ$C)')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(temperature)
